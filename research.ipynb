# %%
# strategy_path = "qms"

# # read all files in the strategy folder rename them to the first three characters
# import os
# import shutil
# import sys

# files =   os.listdir(strategy_path)
# for file in files:
#     if file.endswith(".json"):
#         new_name = file[:4].strip() + ".json"
#         os.rename(os.path.join(strategy_path, file), os.path.join(strategy_path, new_name))

# %%
import
# Out:
# lean object-store set 'subsystems/15-1 Market Mix 2 Subsystem #6 - TLT.json' 'qms/15-1 Market Mix 2 Subsystem #6 - TLT.json'
# Usage: lean object-store set [OPTIONS]
#
# Try 'lean object-store set --help' for help or go to the following url for a
# list of common errors:
# https://www.lean.io/docs/v2/lean-cli/key-concepts/troubleshooting#02-Common-Erro
# rs
#
# Error: Got unexpected extra arguments ('subsystems/15-1 Market Mix 2 Subsystem
# #6 - TLT.json' 'qms/15-1 Market Mix 2 Subsystem #6 - TLT.json')
# lean object-store set 'subsystems/#10 - SVIX 4TLT l Jaewon l 07 Feb 2024.json' 'qms/#10 - SVIX 4TLT l Jaewon l 07 Feb 2024.json'
# Usage: lean object-store set [OPTIONS]
#
# Try 'lean object-store set --help' for help or go to the following url for a
# list of common errors:
# https://www.lean.io/docs/v2/lean-cli/key-concepts/troubleshooting#02-Common-Erro
# rs
#
# Error: Got unexpected extra arguments ('subsystems/#10 - SVIX 4TLT l Jaewon l 07
# Feb 2024.json' 'qms/#10 - SVIX 4TLT l Jaewon l 07 Feb 2024.json')
# lean object-store set 'subsystems/13-1 Total Market 1 Subsystem #3 - Golden Rotator.json' 'qms/13-1 Total Market 1 Subsystem #3 - Golden Rotator.json'
# Usage: lean object-store set [OPTIONS]
#
# Try 'lean object-store set --help' for help or go to the following url for a
# list of common errors:
# https://www.lean.io/docs/v2/lean-cli/key-concepts/troubleshooting#02-Common-Erro
# rs
#
# Error: Got unexpected extra arguments ('subsystems/13-1 Total Market 1 Subsystem
# #3 - Golden Rotator.json' 'qms/13-1 Total Market 1 Subsystem #3 - Golden
# Rotator.json')
# lean object-store set 'subsystems/3-1 MB Market Mix 1 Subsystem#4.json' 'qms/3-1 MB Market Mix 1 Subsystem#4.json'
# Usage: lean object-store set [OPTIONS]
#
# Try 'lean object-store set --help' for help or go to the following url for a
# list of common errors:
# https://www.lean.io/docs/v2/lean-cli/key-concepts/troubleshooting#02-Common-Erro
# rs
#
# Error: Got unexpected extra arguments ('subsystems/3-1 MB Market Mix 1
# Subsystem#4.json' 'qms/3-1 MB Market Mix 1 Subsystem#4.json')
# lean object-store set 'subsystems/15-1 Market Mix 2 Subsystem #1 - TMV Momentum.json' 'qms/15-1 Market Mix 2 Subsystem #1 - TMV Momentum.json'
# Usage: lean object-store set [OPTIONS]
#
# Try 'lean object-store set --help' for help or go to the following url for a
# list of common errors:
# https://www.lean.io/docs/v2/lean-cli/key-concepts/troubleshooting#02-Common-Erro
# rs
#
# Error: Got unexpected extra arguments ('subsystems/15-1 Market Mix 2 Subsystem
# #1 - TMV Momentum.json' 'qms/15-1 Market Mix 2 Subsystem #1 - TMV
# Momentum.json')
# lean object-store set 'subsystems/5-1 Bull only vs Bear only Subsytem#3.json' 'qms/5-1 Bull only vs Bear only Subsytem#3.json'
# Usage: lean object-store set [OPTIONS]
#
# Try 'lean object-store set --help' for help or go to the following url for a
# list of common errors:
# https://www.lean.io/docs/v2/lean-cli/key-concepts/troubleshooting#02-Common-Erro
# rs
#
# Error: Got unexpected extra arguments ('subsystems/5-1 Bull only vs Bear only
# Subsytem#3.json' 'qms/5-1 Bull only vs Bear only Subsytem#3.json')
# lean object-store set 'subsystems/6-1 Jaewon's Market Mix Subsystem #2 - WOOD_XLU Canaries Leverage.json' 'qms/6-1 Jaewon's Market Mix Subsystem #2 - WOOD_XLU Canaries Leverage.json'
# Usage: lean object-store set [OPTIONS]
#
# Try 'lean object-store set --help' for help or go to the following url for a
# list of common errors:
# https://www.lean.io/docs/v2/lean-cli/key-concepts/troubleshooting#02-Common-Erro
# rs
#
# Error: Got unexpected extra arguments ('subsystems/6-1 Jaewon's Market Mix
# Subsystem #2 - WOOD_XLU Canaries Leverage.json' 'qms/6-1 Jaewon's Market Mix
# Subsystem #2 - WOOD_XLU Canaries Leverage.json')
# lean object-store set 'subsystems/15-1 Market Mix 2 Subsystem #4 - TLT vs PSQ.json' 'qms/15-1 Market Mix 2 Subsystem #4 - TLT vs PSQ.json'
# Usage: lean object-store set [OPTIONS]
#
# Try 'lean object-store set --help' for help or go to the following url for a
# list of common errors:
# https://www.lean.io/docs/v2/lean-cli/key-concepts/troubleshooting#02-Common-Erro
# rs
#
# Error: Got unexpected extra arguments ('subsystems/15-1 Market Mix 2 Subsystem
# #4 - TLT vs PSQ.json' 'qms/15-1 Market Mix 2 Subsystem #4 - TLT vs PSQ.json')
# lean object-store set 'subsystems/3-1 MB Market Mix 1 Subsystem#8.json' 'qms/3-1 MB Market Mix 1 Subsystem#8.json'
# Usage: lean object-store set [OPTIONS]
#
# Try 'lean object-store set --help' for help or go to the following url for a
# list of common errors:
# https://www.lean.io/docs/v2/lean-cli/key-concepts/troubleshooting#02-Common-Erro
# rs
#
# Error: Got unexpected extra arguments ('subsystems/3-1 MB Market Mix 1
# Subsystem#8.json' 'qms/3-1 MB Market Mix 1 Subsystem#8.json')
# lean object-store set 'subsystems/11-1 Neo 60_40 Subsystem #7 - Black Swan Catcher.json' 'qms/11-1 Neo 60_40 Subsystem #7 - Black Swan Catcher.json'
# Usage: lean object-store set [OPTIONS]
#
# Try 'lean object-store set --help' for help or go to the following url for a
# list of common errors:
# https://www.lean.io/docs/v2/lean-cli/key-concepts/troubleshooting#02-Common-Erro
# rs
#
# Error: Got unexpected extra arguments ('subsystems/11-1 Neo 60_40 Subsystem #7 -
# Black Swan Catcher.json' 'qms/11-1 Neo 60_40 Subsystem #7 - Black Swan
# Catcher.json')
# lean object-store set 'subsystems/6-1 Jaewon's Market Mix Subsystem #1 - Canary Leverage.json' 'qms/6-1 Jaewon's Market Mix Subsystem #1 - Canary Leverage.json'
# Usage: lean object-store set [OPTIONS]
#
# Try 'lean object-store set --help' for help or go to the following url for a
# list of common errors:
# https://www.lean.io/docs/v2/lean-cli/key-concepts/troubleshooting#02-Common-Erro
# rs
#
# Error: Got unexpected extra arguments ('subsystems/6-1 Jaewon's Market Mix
# Subsystem #1 - Canary Leverage.json' 'qms/6-1 Jaewon's Market Mix Subsystem #1 -
# Canary Leverage.json')
# lean object-store set 'subsystems/9-1 InVol FTLTs Subsytem #1 - Quicks.json' 'qms/9-1 InVol FTLTs Subsytem #1 - Quicks.json'
# Usage: lean object-store set [OPTIONS]
#
# Try 'lean object-store set --help' for help or go to the following url for a
# list of common errors:
# https://www.lean.io/docs/v2/lean-cli/key-concepts/troubleshooting#02-Common-Erro
# rs
#
# Error: Got unexpected extra arguments ('subsystems/9-1 InVol FTLTs Subsytem #1 -
# Quicks.json' 'qms/9-1 InVol FTLTs Subsytem #1 - Quicks.json')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 15
#      13 args = [f"'{key}'", f"'{fullname}'"]
#      14 print(' '.join(command + args))
# ---> 15 run(command + args)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.3/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.3/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:1201, in Popen.communicate(self, input, timeout)
#    1199         stderr = self.stderr.read()
#    1200         self.stderr.close()
# -> 1201     self.wait()
#    1202 else:
#    1203     if timeout is not None:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.3/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.3/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:2053, in Popen._wait(self, timeout)
#    2051 if self.returncode is not None:
#    2052     break  # Another thread waited.
# -> 2053 (pid, sts) = self._try_wait(0)
#    2054 # Check the pid and loop as waitpid has been known to
#    2055 # return 0 even without WNOHANG in odd situations.
#    2056 # http://bugs.python.org/issue14396.
#    2057 if pid == self.pid:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.3/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:2011, in Popen._try_wait(self, wait_flags)
#    2009 """All callers to this function MUST hold self._waitpid_lock."""
#    2010 try:
# -> 2011     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2012 except ChildProcessError:
#    2013     # This happens if SIGCLD is set to be ignored or waiting
#    2014     # for child processes has otherwise been disabled for our
#    2015     # process.  This child is dead, we can't get the status.
#    2016     pid = self.pid
#
# KeyboardInterrupt:
